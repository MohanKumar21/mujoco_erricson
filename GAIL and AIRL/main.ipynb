# %%
import os
import argparse
from datetime import datetime
import torch
from utils.SAC import SAC
from utils.env import make_env
from utils.trainer import Trainer

def run(args):
    env = make_env(args.env_id)
    env_test = make_env(args.env_id)

    algo = SAC(
        state_shape=env.observation_space.shape,
        action_shape=env.action_space.shape,
        device=torch.device("cuda" if args.cuda else "cpu"),
        seed=args.seed
    )

    time = datetime.now().strftime("%Y%m%d-%H%M")
    log_dir = os.path.join(
        'logs', args.env_id, 'sac', f'seed{args.seed}-{time}')

    trainer = Trainer(
        env=env,
        env_test=env_test,
        algo=algo,
        log_dir=log_dir,
        num_steps=args.num_steps,
        eval_interval=args.eval_interval,
        seed=args.seed
    )
    trainer.train()

args = argparse.Namespace(
    env_id = 'InvertedPendulum-v4',
    seed = 0,
    num_steps = 100000,
    cuda = True)
run(
    args
)

# %%
import gymnasium as gym
env = gym.make('InvertedPendulum-v4')

# %%
env.reset()
# Out:
# (array([ 0.00769388,  0.00333762,  0.00876472, -0.0037946 ]), {})

# %%
state, _ = env.reset()
print(state)
# Out:
# [-0.00748317  0.00526792 -0.0001853  -0.00792097]

# %%
test_env = gym.make('InvertedPendulum-v4')
print(test_env.reset())
test_env.close()
# Out:
# (array([ 0.0068468 ,  0.00772261, -0.00960236,  0.00707424]), {})

# %%
env.step(env.action_space.sample())
# Out:
# (array([ 0.01434256, -0.01126657,  0.32283625, -0.71925803]),
#  1.0,
#  False,
#  False,
#  {})

# %%
env.observation_space, env.action_space
# Out:
# (Box(-inf, inf, (4,), float64), Box(-3.0, 3.0, (1,), float32))

# %%
args = argparse.Namespace(
    env_id = 'InvertedPendulum-v4',
    seed = 0,
    num_steps = 100000,
    cuda = True)
run(
    args
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 6
#       1 args = argparse.Namespace(
#       2     env_id = 'InvertedPendulum-v4',
#       3     seed = 0,
#       4     num_steps = 100000,
#       5     cuda = True)
# ----> 6 run(
#       7     args
#       8 )
#
# Cell In[2], line 13, in run(args)
#      10 env = make_env(args.env_id)
#      11 env_test = make_env(args.env_id)
# ---> 13 algo = SAC(
#      14     state_shape=env.observation_space.shape,
#      15     action_shape=env.action_space.shape,
#      16     device=torch.device("cuda" if args.cuda else "cpu"),
#      17     seed=args.seed
#      18 )
#      20 time = datetime.now().strftime("%Y%m%d-%H%M")
#      21 log_dir = os.path.join(
#      22     'logs', args.env_id, 'sac', f'seed{args.seed}-{time}')
#
# File d:\OneDrive - smail.iitm.ac.in\Dual Degree project\Experiments\GAIL and AIRL\utils\SAC.py:14, in SAC.__init__(self, state_shape, action_shape, device, seed, gamma, batch_size, buffer_size, lr_actor, lr_critic, lr_alpha, units_actor, units_critic, start_steps, tau)
#      11 def __init__(self, state_shape, action_shape, device, seed, gamma = 0.99, batch_size = 256,
#      12              buffer_size = 10**6, lr_actor = 3e-4, lr_critic = 3e-4, lr_alpha = 3e-4, units_actor = (256,256),
#      13              units_critic = (256,256), start_steps = 10000, tau = 5e-3):
# ---> 14     super().__init(state_shape, action_shape, device, seed, gamma)
#      16     self.buffer = Buffer(
#      17         buffer_size = buffer_size,
#      18         state_shape = state_shape,
#      19         action_shape = action_shape,
#      20         device = device
#      21     )
#      23     self.actor = StateDependentPolicy(
#      24         state_shape = state_shape,
#      25         action_shape = action_shape,
#      26         hidden_units = units_actor,
#      27         hidden_activation = nn.ReLU(inplace = True),
#      28     ).to(device)
#
# AttributeError: 'super' object has no attribute '_SAC__init'

# %%
# import gymnasium as gym
# env = gym.make("InvertedPendulum-v2", render_mode="human")
# observation, info = env.reset(seed = 42)
# for _ in range(1000):
#     action = env.action_space.sample()
#     observation, reward, done, turnc, info = env.step(action)
#     if done or turnc:
#         observation = env.reset()
# env.close()

# %%
import torch

# %%
model = torch.load('Final/disc.pth')

# %%
model
# Out:
# OrderedDict([('g.0.weight',
#               tensor([[ 4.3666e-01,  2.1526e-01,  2.7205e-01, -3.6061e-01],
#                       [ 9.5484e-02, -4.7686e-02, -2.3420e-01,  1.0519e-01],
#                       [ 1.9766e-01, -3.4511e-01, -6.2845e-02,  1.2974e-01],
#                       [ 4.8908e-01, -4.0818e-01,  4.4691e-01, -5.4010e-02],
#                       [ 1.1730e-01, -4.2562e-01, -4.3420e-01, -2.5175e-01],
#                       [-3.1360e-02,  9.0418e-02,  4.5270e-01, -8.8364e-02],
#                       [ 3.5031e-01, -4.2547e-01,  2.8572e-01, -4.3811e-01],
#                       [-4.8079e-01,  2.9433e-01, -3.3250e-01, -2.7929e-01],
#                       [-3.0064e-01, -1.4040e-01,  2.3896e-01,  2.5422e-01],
#                       [-3.7040e-01,  4.4047e-02, -4.0750e-01, -4.2675e-01],
#                       [-1.3231e-01, -4.7912e-02,  2.4451e-01,  2.1933e-01],
#                       [ 1.1892e-01,  3.7667e-01, -6.2998e-02, -4.1033e-02],
#                       [ 4.8950e-01,  3.0957e-02,  3.4657e-01, -2.5481e-01],
#                       [ 3.2639e-01,  2.9274e-01,  3.9911e-01, -3.0233e-01],
#                       [-4.7087e-01,  9.4651e-02, -5.8126e-02,  4.7909e-01],
#                       [-1.7296e-01, -2.1421e-01,  7.2364e-02, -3.9409e-01],
#                       [-4.1682e-01,  3.1577e-01,  1.0925e-01,  9.2669e-02],
#                       [-7.0943e-02,  2.8460e-01, -1.8844e-01,  1.5728e-01],
#                       [ 1.7306e-01,  1.2356e-01, -3.3538e-01, -4.6879e-01],
#                       [-2.4448e-01, -4.2691e-01, -4.3865e-01, -1.7050e-01],
#                       [-5.6267e-02,  7.1945e-02, -2.5587e-01, -3.2418e-01],
#                       [-1.2585e-01,  2.9769e-01,  2.6728e-01,  4.7105e-01],
#                       [ 2.2541e-01,  3.6372e-01,  2.5313e-03, -3.0257e-01],
#                       [ 1.4837e-01,  4.4063e-01, -1.8102e-01, -9.8370e-03],
#                       [-4.3887e-01,  3.9137e-01, -4.0010e-01, -2.1827e-01],
#                       [-9.4434e-04, -2.4379e-01, -2.6167e-03, -2.7059e-01],
#                       [ 4.7907e-01, -2.8465e-01,  7.5206e-02, -4.7230e-01],
#                       [ 6.4546e-02,  3.2727e-01, -3.1914e-01, -1.0407e-01],
#                       [-2.0632e-02, -1.5802e-02,  9.4931e-02,  4.0579e-01],
#                       [-1.4156e-01,  1.6224e-01, -4.0542e-01, -2.9630e-01],
#                       [-3.6588e-01,  1.0982e-01,  8.2229e-02,  4.8310e-01],
#                       -1.4184e-02, -9.0982e-02, -6.5232e-02,  2.8389e-02, -8.5626e-02,
#                        6.3032e-02,  8.6205e-02,  3.7833e-03, -1.2284e-02, -4.7731e-03,
#                       -3.8228e-02,  1.0205e-01, -6.1753e-02, -6.9755e-02, -3.5788e-02,
#                       -9.6886e-03, -5.9558e-02, -1.9510e-02, -2.4916e-02,  8.8170e-02,
#                       -3.8058e-02,  3.2020e-03, -4.2603e-03, -1.0177e-02, -7.4032e-02,
#                        4.3236e-02,  7.0435e-02,  3.7399e-03, -2.3498e-02,  2.9842e-02,
#                        2.5169e-05, -1.6276e-02,  3.4048e-02,  5.7042e-02,  5.2703e-02,
#                       -4.6930e-02,  1.9480e-02, -4.6059e-02,  1.4109e-02, -2.9665e-02])),
#              ('g.4.weight',
#               tensor([[-0.0081,  0.0270, -0.0039, -0.0828, -0.0717, -0.0258, -0.0613, -0.0946,
#                        -0.0824, -0.0436, -0.0694,  0.0525,  0.0415, -0.1027, -0.0125, -0.0139,
#                        -0.0047,  0.0438, -0.0406,  0.0939,  0.0552, -0.1037,  0.0123,  0.0429,
#                        -0.0119,  0.0237, -0.0143,  0.0462, -0.0760,  0.0075,  0.0892,  0.0537,
#                        -0.0950,  0.0457,  0.0156, -0.0359,  0.0588,  0.0631,  0.0483, -0.0720,
#                        -0.0787,  0.0199,  0.0907, -0.0564,  0.0640, -0.0013, -0.0272, -0.0577,
#                         0.0542,  0.0320, -0.0876,  0.0666, -0.0471, -0.0954,  0.0027,  0.0735,
#                         0.0842, -0.0614,  0.0229,  0.0424,  0.0499, -0.0761, -0.0945, -0.0606,
#                        -0.0186, -0.0594,  0.0612, -0.1002,  0.0708, -0.0328,  0.0710, -0.0958,
#                        -0.0043, -0.0736, -0.1039,  0.0475,  0.0862, -0.0424, -0.0411, -0.0511,
#                        -0.0950,  0.0663, -0.0041, -0.0082,  0.0475, -0.0087, -0.0360, -0.0869,
#                        -0.0378,  0.0483,  0.0373,  0.0442, -0.0723, -0.1025, -0.0239, -0.0946,
#                         0.0132,  0.0428,  0.0400, -0.0835]])),
#              ('g.4.bias', tensor([0.0166])),
#              ('h.0.weight',
#               tensor([[ 0.3041, -0.1247,  0.4701,  0.2818],
#                       [-0.3407,  0.1120,  0.4222, -0.1666],
#                       [ 0.1710,  0.0586,  0.1943, -0.0613],
#                       [-0.3832,  0.0655,  0.2560, -0.1591],
#                       [ 0.1813,  0.0069, -0.2593, -0.3234],
#                       [-0.2529,  0.3292,  0.0411,  0.2172],
#                       [ 0.1045, -0.2592,  0.0073, -0.0131],
#                       [ 0.1656, -0.4565, -0.2293,  0.3115],
#                       [-0.4471,  0.0892,  0.2793,  0.2045],
#                       [ 0.2024,  0.1693, -0.2374,  0.0710],
#                       [ 0.2417, -0.3544,  0.4126, -0.2487],
#                       [ 0.0020, -0.0654, -0.0122,  0.5009],
#                       [ 0.0035,  0.3980, -0.3629, -0.0798],
#                       [-0.4792, -0.2865,  0.3989, -0.2852],
#                       [ 0.2946, -0.2544,  0.4127, -0.0528],
#                       [-0.1167,  0.4670, -0.0840,  0.3616],
#                       [ 0.0895,  0.3742, -0.1671, -0.0412],
#                       [-0.2033, -0.2845, -0.4325, -0.0668],
#                       [ 0.4862,  0.0751,  0.1821, -0.1142],
#                       [-0.0586,  0.3551, -0.4423, -0.0149],
#                       [-0.3878, -0.2807,  0.3668,  0.2540],
#                       [-0.2884,  0.2028,  0.3072, -0.2947],
#                       [ 0.2241, -0.4121, -0.0938,  0.0786],
#                       [-0.0370, -0.2212, -0.3419, -0.1249],
#                       [-0.2664, -0.3401,  0.1395,  0.1560],
#                       [-0.4036, -0.2029, -0.2899, -0.2127],
#                       [ 0.0454, -0.2994,  0.4858,  0.1505],
#                       [ 0.1932,  0.1410, -0.3288, -0.0122],
#                       [-0.4377, -0.2689,  0.2150, -0.3889],
#                       [ 0.4361,  0.2092,  0.0300,  0.0144],
#                       [-0.1687,  0.0829,  0.2046, -0.1989],
#                       [-0.2428, -0.1245, -0.2071, -0.3869],
#                       [-0.3838, -0.1713,  0.3329,  0.3304],
#                       [-0.2100,  0.4745, -0.2534,  0.0250],
#                       [ 0.4643,  0.1070, -0.2492,  0.1110],
#                       [-0.4192,  0.1659, -0.3882,  0.3778],
#                       [-0.1585, -0.0180, -0.0964, -0.4569],
#                       [ 0.4310,  0.2827,  0.3605,  0.4500],
#                       [ 0.4822,  0.4551,  0.2129,  0.1492],
#                       [-0.4640,  0.1453,  0.0199, -0.0648],
#                       [ 0.0600, -0.1463,  0.4682, -0.0541],
#                       [-0.4725,  0.1172,  0.4549, -0.3036],
#                       [-0.0588, -0.0535, -0.4643,  0.1659],
#                       [-0.3316, -0.1322, -0.1667,  0.2901],
#                       [-0.4534,  0.1049,  0.3117,  0.2204],
#                       [-0.2468,  0.1026,  0.1745,  0.4259],
#                       [ 0.1853,  0.0259, -0.3019,  0.2043],
#                       [ 0.0758,  0.4139,  0.4508,  0.3175],
#                       [ 0.0682, -0.3082,  0.4739, -0.3994],
#                       [-0.0405, -0.2137,  0.3220,  0.4119],
#                       [-0.3396,  0.1745,  0.3934, -0.3394],
#                       [-0.2300, -0.4089, -0.1704, -0.2234],
#                       [ 0.3534,  0.0554, -0.2329, -0.3690],
#                       [ 0.0940,  0.0910, -0.2679,  0.1270],
#                       [-0.3485, -0.4780, -0.3018, -0.4534],
#                       [ 0.3134,  0.4806,  0.4174, -0.2618],
#                       [-0.0130, -0.2770, -0.1808,  0.1420],
#                       [ 0.4194,  0.1742,  0.0587, -0.0999],
#                       [ 0.2110, -0.0640, -0.4134,  0.0411],
#                       [ 0.4213,  0.3529, -0.0442, -0.3186],
#                       [-0.1942, -0.0155, -0.2045, -0.2226],
#                       [ 0.2846, -0.4571, -0.0569,  0.3900],
#                       [ 0.1695, -0.0453,  0.3707, -0.2881],
#                       [ 0.0557,  0.4895,  0.0145, -0.4656],
#                       [-0.3746, -0.4386, -0.2620,  0.1615],
#                       [-0.2307,  0.0247, -0.4908, -0.0956],
#                       [ 0.1958,  0.2112,  0.4192,  0.2322],
#                       [-0.3743,  0.3071, -0.3577, -0.0802],
#                       [ 0.2595,  0.4051,  0.0723,  0.2014],
#                       [ 0.2793,  0.4886,  0.3757, -0.1882],
#                       [ 0.1574, -0.4501, -0.1336,  0.1626],
#                       [ 0.2942,  0.3088,  0.0579, -0.0759],
#                       [ 0.3645,  0.3774, -0.1858,  0.0696],
#                       [-0.0843,  0.2382, -0.3243, -0.3088],
#                       [-0.0986,  0.4142,  0.1016,  0.1651],
#                       [ 0.1889,  0.4768, -0.2433, -0.0264],
#                       [ 0.2062,  0.0405,  0.4113, -0.4444],
#                       [-0.0956, -0.3249,  0.1143,  0.2150],
#                       [-0.2858,  0.4395,  0.0543, -0.4557],
#                       [-0.4866,  0.1658,  0.1260, -0.3161],
#                       [ 0.1768,  0.3294,  0.3713, -0.0660],
#                       [-0.1671,  0.1813, -0.2806, -0.4545],
#                       [-0.1181,  0.0617,  0.1521,  0.3912],
#                       [-0.0712, -0.3119,  0.0083,  0.1392],
#                       [ 0.4663,  0.3368, -0.4529,  0.0972],
#                       [ 0.2724, -0.1653,  0.2340, -0.0347],
#                       [-0.2070, -0.2133,  0.2864,  0.4153],
#                       [ 0.4423,  0.0822, -0.0149,  0.3074],
#                       [ 0.3952, -0.0365, -0.1444, -0.3117],
#                       [ 0.2156, -0.4336,  0.1766, -0.4227],
#                       [ 0.4728, -0.4711, -0.2982, -0.0692],
#                       [-0.1263, -0.0853, -0.2696, -0.0846],
#                       [-0.3353, -0.4829, -0.4782,  0.3960],
#                       [ 0.1257,  0.4499,  0.0638, -0.1676],
#                       [-0.0716, -0.4755,  0.4566,  0.3233],
#                       [-0.2187,  0.1325,  0.3204, -0.2309],
#                       [-0.3029, -0.3295, -0.4905,  0.4917],
#                       [ 0.0062, -0.0703,  0.0479, -0.3755],
#                       [ 0.3752, -0.4821,  0.3893, -0.3161],
#                       [ 0.2159, -0.0036, -0.4816,  0.4131]])),
#              ('h.0.bias',
#               tensor([ 0.3001,  0.1271,  0.2351, -0.4656,  0.1223,  0.1884,  0.3344, -0.4935,
#                       -0.0049,  0.3911, -0.3717, -0.3162,  0.4613,  0.1008, -0.1022, -0.2726,
#                        0.0775,  0.0749,  0.4059, -0.1035,  0.2064,  0.2537,  0.1718, -0.3284,
#                        0.1837, -0.0777, -0.3375, -0.1814, -0.1331, -0.0957, -0.0401,  0.3949,
#                        0.2357,  0.1625,  0.2385,  0.4299, -0.3489, -0.0997, -0.3707, -0.2519,
#                        0.2142,  0.4177,  0.1754, -0.1142, -0.2340, -0.3359,  0.1251, -0.4035,
#                        0.3963, -0.0263,  0.0540, -0.2576, -0.2075,  0.1678,  0.0924,  0.2549,
#                        0.3311, -0.3363,  0.4582,  0.0242, -0.4174,  0.2879, -0.2846,  0.3796,
#                       -0.2397, -0.2158,  0.2043,  0.4773, -0.3657,  0.2103, -0.3942,  0.4069,
#                       -0.0152,  0.2836, -0.3038,  0.1553,  0.4005,  0.2690,  0.3430,  0.3493,
#                       -0.1169, -0.4135,  0.0570, -0.3862, -0.4899,  0.2117,  0.3661,  0.1054,
#                       -0.4306,  0.0426,  0.3669,  0.0690, -0.3969, -0.0994, -0.3448,  0.0357,
#                       -0.2396, -0.4718,  0.1364, -0.1338])),
#              ('h.2.weight',
#               tensor([[-0.0883,  0.0881, -0.0271,  ...,  0.0279,  0.0364,  0.0406],
#                       [ 0.0439,  0.0520,  0.0326,  ..., -0.0080,  0.0085, -0.0958],
#                       [-0.0590,  0.0484,  0.0353,  ...,  0.0100, -0.0769, -0.0585],
#                       ...,
#                       [ 0.0527, -0.0905, -0.0684,  ...,  0.0391,  0.0712, -0.0038],
#                       [-0.0179, -0.0926, -0.0438,  ...,  0.0997, -0.0423,  0.0353],
#                       [-0.0813,  0.0451, -0.0302,  ...,  0.0671, -0.0059, -0.0318]])),
#              ('h.2.bias',
#               tensor([-0.0829, -0.0318,  0.0577,  0.0736,  0.0118, -0.0900,  0.0976, -0.0772,
#                        0.0744,  0.0142,  0.0930,  0.0437, -0.0839, -0.0456,  0.0857, -0.0008,
#                        0.0664,  0.1002, -0.0005,  0.0739, -0.0784, -0.0532,  0.0760, -0.0932,
#                        0.0962,  0.0830, -0.0922, -0.0098,  0.0078, -0.0713, -0.0480,  0.0692,
#                        0.0149, -0.0661,  0.0930,  0.0585, -0.0620,  0.0150, -0.0650, -0.0863,
#                        0.0464, -0.0126,  0.0509, -0.0946, -0.0671,  0.0146,  0.0641, -0.0368,
#                        0.0471, -0.0201, -0.0239,  0.0140, -0.0300, -0.0582, -0.0693, -0.0981,
#                       -0.0670,  0.0396, -0.0924,  0.1045,  0.0078,  0.0163, -0.0224, -0.0837,
#                        0.0320,  0.0145,  0.0178,  0.0888, -0.0671, -0.0665,  0.0938, -0.0462,
#                       -0.0557, -0.0853,  0.0265,  0.1004, -0.0791,  0.0340,  0.0863,  0.0963,
#                        0.0250, -0.0768,  0.0858,  0.0016, -0.0792, -0.0043,  0.0008, -0.0091,
#                        0.0858,  0.0866,  0.0871, -0.0429,  0.0712, -0.0474,  0.0007, -0.0728,
#                       -0.0389,  0.0091, -0.0408, -0.0888])),
#              ('h.4.weight',
#               tensor([[-0.0739,  0.0754, -0.0384,  0.0876,  0.0720, -0.0957,  0.0760,  0.0637,
#                         0.0206,  0.0969, -0.0298,  0.0705, -0.0474, -0.0320, -0.0711,  0.0866,
#                         0.0556,  0.0336, -0.0139,  0.0470, -0.0320,  0.0776,  0.0395,  0.0039,
#                        -0.0389, -0.0210,  0.0857, -0.0013, -0.0778, -0.0463, -0.0507,  0.0474,
#                         0.0852,  0.0949, -0.0861,  0.0564, -0.0090, -0.0633,  0.0832, -0.0276,
#                         0.0048,  0.0667, -0.0255, -0.0968, -0.0019, -0.0027, -0.0801, -0.0853,
#                         0.0714,  0.0940, -0.0395, -0.0874,  0.0521,  0.0275,  0.0039, -0.0614,
#                         0.0253, -0.0460, -0.0159,  0.0494,  0.0736,  0.0128, -0.0876,  0.0856,
#                        -0.0613, -0.0324, -0.0470,  0.0259,  0.0795, -0.0548,  0.0282,  0.0229,
#                        -0.0847,  0.0240,  0.0826,  0.0897,  0.0714, -0.0441, -0.0160,  0.0225,
#                         0.0404,  0.0206,  0.0723,  0.0872, -0.0648, -0.0757,  0.0274, -0.0581,
#                        -0.0005, -0.0948,  0.0709,  0.0706,  0.0357, -0.1014,  0.0264, -0.0132,
#                         0.0586,  0.0591, -0.0405,  0.0924]])),
#              ('h.4.bias', tensor([0.0809]))])
